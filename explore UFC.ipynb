# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('max_columns', 999)

# %%
data = pd.read_csv('ufc_data.csv')

# %%
data.head()
# Out:
#    BPrev  BStreak  B_Age  B_Height                           B_HomeTown  B_ID  \
# 0      1        1   23.0     182.0                         Trento Italy  2783
# 1      0        0   32.0     175.0  Careiro da V��rzea, Amazonas Brazil  2208
# 2      2        0   38.0     172.0                       Kanagawa Japan   721
# 3      0        0   23.0     170.0                       Tijuana Mexico  2825
# 4      3        1   30.0     167.0                      Spokane, WA USA  2260
#
#           B_Location                 B_Name  B_Weight  \
# 0  Mezzocorona Italy         Marvin Vettori        84
# 1   Pharr, Texas USA  Carlos Diego Ferreira        70
# 2        Tokyo Japan          Takanori Gomi        70
# 3     Tijuana Mexico         Brandon Moreno        56
# 4    Spokane, WA USA     Elizabeth Phillips        61
#
#    B__Round1_Grappling_Reversals_Landed   ...    R__Round5_TIP_Ground Time  \
# 0                                   0.0   ...                          NaN
# ...

# %%
fighters = pd.read_csv('fighter_data.csv')

# %%
fights = pd.read_csv('fight_data.csv')

# %%
fights.head()
# Out:
#                          pageurl  eid  mid             event_name  \
# 0  /events/UFC-1-The-Beginning-7  7.0  8.0  UFC 1 - The Beginning
# 1  /events/UFC-1-The-Beginning-7  7.0  7.0  UFC 1 - The Beginning
# 2  /events/UFC-1-The-Beginning-7  7.0  6.0  UFC 1 - The Beginning
# 3  /events/UFC-1-The-Beginning-7  7.0  5.0  UFC 1 - The Beginning
# 4  /events/UFC-1-The-Beginning-7  7.0  4.0  UFC 1 - The Beginning
#
#                         event_org event_date  \
# 0  Ultimate Fighting Championship   11/12/93
# 1  Ultimate Fighting Championship   11/12/93
# 2  Ultimate Fighting Championship   11/12/93
# 3  Ultimate Fighting Championship   11/12/93
# 4  Ultimate Fighting Championship   11/12/93
#
#                                         event_place  \
# 0  McNichols Arena, Denver, Colorado, United States
# 1  McNichols Arena, Denver, Colorado, United States
# 2  McNichols Arena, Denver, Colorado, United States
# 3  McNichols Arena, Denver, Colorado, United States
# ...

# %%
from bs4 import BeautifulSoup
